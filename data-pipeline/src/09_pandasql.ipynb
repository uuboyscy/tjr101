# %%
import pandas as pd
from pandasql import sqldf

# %%
file_path_staff_detail_different_col = "../resource/staff_detail_different_col.csv"
file_path_staff_detail = "../resource/staff_detail.csv"
file_path_staff_samecol = "../resource/staff_samecol.csv"
file_path_staff = "../resource/staff.csv"

staff_detail_different_col_df = pd.read_csv(file_path_staff_detail_different_col)
staff_detail_df = pd.read_csv(file_path_staff_detail)
staff_samecol_df = pd.read_csv(file_path_staff_samecol)
staff_df = pd.read_csv(file_path_staff)

# %%
sql = """select * from staff_df"""
sqldf(sql)
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
sql = """
    select
        sd.ID
        , Level
        , Gender
        , Salary
    from staff_detail_df sd
    left join staff_df s
    on sd.ID = s.ID
"""
sqldf(sql)
# Out:
#     ID Level Gender  Salary
# 0    1     A      M   60000
# 1    1     S      M   60000
# 2    2     A      F   48000
# 3    3     A      M   50000
# 4    3     S      M   50000
# 5    4     A      M   47000
# 6    5     A      M   52000
# 7    5     S      M   52000
# 8    6     A      F   45000
# 9    7     A      M   80000
# 10   7     S      M   80000
# 11   7     M      M   80000
# 12   8     A      F   87000
# 13   8     S      F   87000
# 14   8     M      F   87000

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff_detail_different_col = "../resource/staff_detail_different_col.csv"\nfile_path_staff_detail = "../resource/staff_detail.csv"\nfile_path_staff_samecol = "../resource/staff_samecol.csv"\nfile_path_staff = "../resource/staff.csv"\n\nstaff_detail_different_col_df = pd.read_csv(file_path_staff_detail_different_col)\nstaff_detail_df = pd.read_csv(file_path_staff_detail)\nstaff_samecol_df = pd.read_csv(file_path_staff_samecol)\nstaff_df = pd.read_csv(file_path_staff)',
#   'sql = """select * from staff_df"""\nsqldf(sql)',
# ...

# %%
globals()["staff_df"]
# Out:
#    ID   Name  DeptId  Age Gender  Salary
# 0   1   Mike       2   45      M   60000
# 1   2   Judy       2   30      F   48000
# 2   3  Allen       1   22      M   50000
# 3   4    Tom       2   47      M   47000
# 4   5   Jack       3   36      M   52000
# 5   6   Abby       2   24      F   45000
# 6   7  Trump       1   80      M   80000
# 7   8  Marry       3   29      F   87000

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import pandas as pd\nfrom pandasql import sqldf',
#   'file_path_staff_detail_different_col = "../resource/staff_detail_different_col.csv"\nfile_path_staff_detail = "../resource/staff_detail.csv"\nfile_path_staff_samecol = "../resource/staff_samecol.csv"\nfile_path_staff = "../resource/staff.csv"\n\nstaff_detail_different_col_df = pd.read_csv(file_path_staff_detail_different_col)\nstaff_detail_df = pd.read_csv(file_path_staff_detail)\nstaff_samecol_df = pd.read_csv(file_path_staff_samecol)\nstaff_df = pd.read_csv(file_path_staff)',
#   'sql = """select * from staff_df"""\nsqldf(sql)',
# ...

# %%
print("docker run -d \\n  --name mysql-container \\n  -e MYSQL_ROOT_PASSWORD=passWord \\n  -p 33060:3306 \\n  mysql:latest")
# Out:
# docker run -d \n  --name mysql-container \n  -e MYSQL_ROOT_PASSWORD=passWord \n  -p 33060:3306 \n  mysql:latest
